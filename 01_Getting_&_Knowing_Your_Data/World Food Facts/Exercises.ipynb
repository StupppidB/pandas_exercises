# %% [markdown]
# # Exercise 1

# %% [markdown]
# ### Step 1. Go to https://www.kaggle.com/openfoodfacts/world-food-facts/data

# %% [markdown]
# ### Step 2. Download the dataset to your computer and unzip it.

# %% [markdown]
# ### Step 3. Use the tsv file and assign it to a dataframe called food

# %%
import numpy as np
import pandas as pd

# %%
food = pd.read_csv('../../data/en.openfoodfacts.org.products.csv', sep='\t')
# Out:
# /root/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (0,17,18,19,20,24,25,26,28,44,49,52,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ### Step 4. See the first 5 entries

# %%
food.head(5)
# Out:
#                    code                                                url  \
# 0         0000000000017  http://world-en.openfoodfacts.org/product/0000...
# 1         0000000000031  http://world-en.openfoodfacts.org/product/0000...
# 2    000000000003327986  http://world-en.openfoodfacts.org/product/0000...
# 3         0000000000100  http://world-en.openfoodfacts.org/product/0000...
# 4  00000000001111111111  http://world-en.openfoodfacts.org/product/0000...
#
#                       creator   created_t      created_datetime  \
# 0                     kiliweb  1529059080  2018-06-15T10:38:00Z
# 1                    isagoofy  1539464774  2018-10-13T21:06:14Z
# 2                     kiliweb  1574175736  2019-11-19T15:02:16Z
# 3                       del51  1444572561  2015-10-11T14:09:21Z
# 4  openfoodfacts-contributors  1560020173  2019-06-08T18:56:13Z
#
#    last_modified_t last_modified_datetime                  product_name  \
# ...

# %% [markdown]
# ### Step 5. What is the number of observations in the dataset?

# %%
food.shape[0]
# Out:
# 799506

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
food.shape[1]
# Out:
# 181

# %%
food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 799506 entries, 0 to 799505
# Columns: 181 entries, code to carnitine_100g
# dtypes: float64(122), int64(2), object(57)
# memory usage: 1.1+ GB

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
food.columns
# Out:
# Index(['code', 'url', 'creator', 'created_t', 'created_datetime',
#        'last_modified_t', 'last_modified_datetime', 'product_name',
#        'generic_name', 'quantity',
#        ...
#        'carbon-footprint-from-meat-or-fish_100g', 'nutrition-score-fr_100g',
#        'nutrition-score-uk_100g', 'glycemic-index_100g', 'water-hardness_100g',
#        'choline_100g', 'phylloquinone_100g', 'beta-glucan_100g',
#        'inositol_100g', 'carnitine_100g'],
#       dtype='object', length=181)

# %% [markdown]
# ### Step 8. What is the name of 105th column?

# %%
food.columns[104]
# Out:
# '-gondoic-acid_100g'

# %% [markdown]
# ### Step 9. What is the type of the observations of the 105th column?

# %%
food[food.columns[104]].dtypes
# Out:
# dtype('float64')

# %% [markdown]
# ### Step 10. How is the dataset indexed?

# %%
food.index
# Out:
# RangeIndex(start=0, stop=799506, step=1)

# %% [markdown]
# ### Step 11. What is the product name of the 19th observation?

# %%
food.loc[18].product_name
# Out:
# 'Chocolate n 3'

# %% [markdown]
# # Explore

# %%
pd.set_option('display.max_columns',None)

# %%
food.head(5)
# Out:
#                    code                                                url  \
# 0         0000000000017  http://world-en.openfoodfacts.org/product/0000...
# 1         0000000000031  http://world-en.openfoodfacts.org/product/0000...
# 2    000000000003327986  http://world-en.openfoodfacts.org/product/0000...
# 3         0000000000100  http://world-en.openfoodfacts.org/product/0000...
# 4  00000000001111111111  http://world-en.openfoodfacts.org/product/0000...
#
#                       creator   created_t      created_datetime  \
# 0                     kiliweb  1529059080  2018-06-15T10:38:00Z
# 1                    isagoofy  1539464774  2018-10-13T21:06:14Z
# 2                     kiliweb  1574175736  2019-11-19T15:02:16Z
# 3                       del51  1444572561  2015-10-11T14:09:21Z
# 4  openfoodfacts-contributors  1560020173  2019-06-08T18:56:13Z
#
#    last_modified_t last_modified_datetime                  product_name  \
# ...

# %%
food.product_name.nunique()
# Out:
# 520699

# %%
food.product_name.value_counts()
# Out:
# Comté                                766
# Ice cream                            714
# Filet de poulet                      703
# Emmental                             493
# Soda                                 482
#                                     ...
# Vietnamese Recipe Chicken Sausage      1
# Tariquet classic                       1
# tree ripened papaya                    1
# Biographie Walnüsse                    1
# Vin de bourgogne 2017                  1
# Name: product_name, Length: 520699, dtype: int64

# %%
food.created_datetime.agg(['max','min'])
# Out:
# max    2020-04-24T00:22:25Z
# min    2012-02-09T10:34:56Z
# Name: created_datetime, dtype: object

# %%
food.creator.value_counts()
# Out:
# kiliweb                       342110
# usda-ndb-import               166113
# org-database-usda             132115
# openfoodfacts-contributors     69790
# date-limite-app                10877
#                                ...
# tilmant                            1
# goyourgang                         1
# marlaluise                         1
# jltgpao1122                        1
# grama                              1
# Name: creator, Length: 6785, dtype: int64

# %%
food.brands.value_counts()
# Out:
# Carrefour                                       9037
# Auchan                                          8731
# U                                               5966
# Casino                                          4240
# Bonarea                                         3957
#                                                 ...
# Gator Hammock                                      1
# Happy Day Raw Foods                                1
# Les Trouvailles de Lucile,Fresh Food Village       1
# Nutty Fruity                                       1
# Minoterie de L'écluse                              1
# Name: brands, Length: 72981, dtype: int64

# %%
food.categories.value_counts()
# Out:
# Snacks                                                                                                                                                                                                                              32288
# Snacks, Sweet snacks, Confectioneries                                                                                                                                                                                               13767
# Groceries, Sauces                                                                                                                                                                                                                   13469
# Dairies, Fermented foods, Fermented milk products, Cheeses                                                                                                                                                                          11057
# ...

# %%
food.cities.unique()
# Out:
# array([nan])

# %%
food.countries.value_counts().head(20)
# Out:
# United States            302235
# France                   275495
# en:fr                     55626
# en:france                 29527
# en:es                     19551
# en:FR                     17273
# en:France                  6653
# en:United States           5318
# España                     4945
# Canada                     3668
# en:ca                      3651
# en:be                      3611
# en:spain                   3457
# en:ch                      2728
# en:us                      2519
# Deutschland                2428
# Spain                      2277
# United Kingdom             2142
# France, United States      2114
# en:Germany                 1761
# Name: countries, dtype: int64

# %%
food.loc[food.sugars_100g.sort_values(ascending=False).head(20).index,['code','product_name','sugars_100g']]
# Out:
#                  code                                product_name  sugars_100g
# 128195    51500825648                           Uncrustables PB&J      1800.00
# 147346    68400018902            sidekicks beurre et fines herbes      1600.00
# 163979    71279126036                                    Required       550.00
# 16867          123129                  Vanilla meringues fat free       525.00
# 331425   749826752075                               Breakfast bar       500.00
# 162348    71043007851         Strawberry Raspberry Low Fat Yogurt       433.00
# 307003   704817523492                                   Built Bar       400.00
# 376489   855378004927                    Munchi Mix (Dollar Tree)       400.00
# 444126  2184435001196                                 bananes bio       300.00
# 122026  0048500202746    Tropicana Orange Juice - Orginal No Pulp       275.00
# 674250  3361779998231                 Ketch'up Piment D'espelette       240.00
# ...
